# %%
# Finally !
# !pip install pandas

# %%
import os
import librosa
import numpy as np
import matplotlib.pyplot as plt
import librosa.display

# %%
folder_path = r'/mnt/external_disk/InsectSound1000'
insect_name = 'Aphidoletes_aphidimyza'

# %%
audio_data_dict = {}

# List and filter files based on the insect name
wav_files = [f for f in os.listdir(folder_path) if f.endswith('.wav') and insect_name in f]

# Process files and load audio data
for wav_file in wav_files:
    file_path = os.path.join(folder_path, wav_file)
    try:
        audio_data, sample_rate = librosa.load(file_path, sr=None)
        audio_data_dict[wav_file] = {'audio': audio_data, 'sample_rate': sample_rate}
    except Exception as e:
        print(f"Error loading {wav_file}: {e}")

# %%
def analyze_fft(audio_data, sample_rate, threshold_ratio=0.5):
    n = len(audio_data)
    fft_data = np.fft.fft(audio_data)
    freqs = np.fft.fftfreq(n, d=1/sample_rate)
    positive_freqs = freqs[:n // 2]
    magnitude = np.abs(fft_data[:n // 2])

    # Plot FFT
    # plt.figure(figsize=(10, 5))
    # plt.plot(positive_freqs, magnitude)
    # plt.title("FFT Analysis")
    # plt.xlabel("Frequency (Hz)")
    # plt.ylabel("Amplitude")
    # plt.grid()
    # plt.show()

    dominant_frequency = positive_freqs[np.argmax(magnitude)]
    peak_magnitude = np.max(magnitude)
    threshold = threshold_ratio * peak_magnitude
    dominant_freqs = positive_freqs[magnitude >= threshold]

    print(f"Dominant frequency: {dominant_frequency:.2f} Hz")
    return dominant_frequency, dominant_freqs

# %%
def plot_spectrogram(audio_data, sample_rate):
    plt.figure(figsize=(10, 5))
    spectrogram = librosa.stft(audio_data)
    spectrogram_db = librosa.amplitude_to_db(np.abs(spectrogram), ref=np.max)
    librosa.display.specshow(spectrogram_db, sr=sample_rate, x_axis='time', y_axis='linear', cmap='viridis')
    plt.colorbar(format="%+5.0f dB")
    plt.title("Spectrogram")
    plt.xlabel("Time (s)")
    plt.ylabel("Frequency (Hz)")
    plt.ylim(0, 200)
    plt.show()

# %%
dominant_freqs_all = []
zcr_all = []
mean_amplitude_all = []
max_amplitude_all = []
min_amplitude_all = []

for file_name, data in audio_data_dict.items():
    audio = data['audio']
    sample_rate = data['sample_rate']
    
    print(f"Analyzing file: {file_name}")
    
    # Analyze FFT and dominant frequencies
    dominant_frequency, dominant_freqs = analyze_fft(audio, sample_rate)
    dominant_freqs_all.append(dominant_frequency)
    
    # Calculate Zero-Crossing Rate (ZCR)
    zcr = librosa.zero_crossings(audio, pad=False)
    zcr_rate = sum(zcr) / len(audio)
    zcr_all.append(zcr_rate)
    
    # Basic amplitude stats
    mean_amplitude = np.mean(audio)
    max_amplitude = np.max(audio)
    min_amplitude = np.min(audio)
    mean_amplitude_all.append(mean_amplitude)
    max_amplitude_all.append(max_amplitude)
    min_amplitude_all.append(min_amplitude)

    print("-" * 50)  # Separator between file outputs

# Calculate min/max ranges for each feature
dominant_freq_min = np.min(dominant_freqs_all)
dominant_freq_max = np.max(dominant_freqs_all)

zcr_min = np.min(zcr_all)
zcr_max = np.max(zcr_all)

mean_amplitude_min = np.min(mean_amplitude_all)
mean_amplitude_max = np.max(mean_amplitude_all)

max_amplitude_min = np.min(max_amplitude_all)
max_amplitude_max = np.max(max_amplitude_all)

min_amplitude_min = np.min(min_amplitude_all)
min_amplitude_max = np.max(min_amplitude_all)

# Print ranges
print(f"Dominant Frequency Range: {dominant_freq_min:.2f} Hz - {dominant_freq_max:.2f} Hz")
print(f"Zero-Crossing Rate Range: {zcr_min:.5f} - {zcr_max:.5f}")
print(f"Mean Amplitude Range: {mean_amplitude_min:.3f} - {mean_amplitude_max:.3f}")
print(f"Max Amplitude Range: {max_amplitude_min:.3f} - {max_amplitude_max:.3f}")
print(f"Min Amplitude Range: {min_amplitude_min:.3f} - {min_amplitude_max:.3f}")
# Out:
# Analyzing file: 202253-16-31_Aphidoletes_aphidimyza_000029_s3_ch2.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 2022324-13-48_Aphidoletes_aphidimyza_000071_s6_ch0.wav
# Dominant frequency: 19.20 Hz
# --------------------------------------------------
# Analyzing file: 2022323-13-1_Aphidoletes_aphidimyza_000058_s16_ch0.wav
# Dominant frequency: 16.40 Hz
# --------------------------------------------------
# Analyzing file: 2022323-13-1_Aphidoletes_aphidimyza_000076_s36_ch0.wav
# Dominant frequency: 18.80 Hz
# --------------------------------------------------
# Analyzing file: 2022324-13-48_Aphidoletes_aphidimyza_000060_s39_ch0.wav
# Dominant frequency: 28.80 Hz
# --------------------------------------------------
# Analyzing file: 202253-16-31_Aphidoletes_aphidimyza_000003_s4_ch0.wav
# Dominant frequency: 28.80 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000021_s41_ch0.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000015_s5_ch0.wav
# Dominant frequency: 39.20 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000044_s9_ch3.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202252-18-31_Aphidoletes_aphidimyza_000024_s96_ch3.wav
# Dominant frequency: 20.80 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000024_s66_ch3.wav
# Dominant frequency: 39.60 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000024_s27_ch3.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 2022324-13-48_Aphidoletes_aphidimyza_000038_s16_ch0.wav
# Dominant frequency: 16.00 Hz
# --------------------------------------------------
# Analyzing file: 202253-16-31_Aphidoletes_aphidimyza_000011_s47_ch1.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000009_s5_ch1.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000012_s102_ch3.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202253-16-31_Aphidoletes_aphidimyza_000021_s80_ch2.wav
# Dominant frequency: 139.20 Hz
# --------------------------------------------------
# Analyzing file: 202252-18-31_Aphidoletes_aphidimyza_000057_s45_ch0.wav
# Dominant frequency: 18.80 Hz
# --------------------------------------------------
# Analyzing file: 202253-16-31_Aphidoletes_aphidimyza_000038_s30_ch1.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000026_s77_ch3.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000016_s128_ch3.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000032_s2_ch3.wav
# Dominant frequency: 29.60 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000010_s67_ch1.wav
# Dominant frequency: 39.60 Hz
# --------------------------------------------------
# Analyzing file: 202253-16-31_Aphidoletes_aphidimyza_000039_s17_ch3.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 2022323-13-1_Aphidoletes_aphidimyza_000050_s3_ch0.wav
# Dominant frequency: 15.60 Hz
# --------------------------------------------------
# Analyzing file: 2022323-13-1_Aphidoletes_aphidimyza_000052_s8_ch2.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 2022323-13-1_Aphidoletes_aphidimyza_000077_s66_ch0.wav
# Dominant frequency: 18.80 Hz
# --------------------------------------------------
# Analyzing file: 202253-16-31_Aphidoletes_aphidimyza_000052_s6_ch0.wav
# Dominant frequency: 19.60 Hz
# --------------------------------------------------
# Analyzing file: 202253-16-31_Aphidoletes_aphidimyza_000025_s71_ch1.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202253-16-31_Aphidoletes_aphidimyza_000015_s64_ch0.wav
# Dominant frequency: 36.00 Hz
# --------------------------------------------------
# Analyzing file: 202252-18-31_Aphidoletes_aphidimyza_000031_s82_ch3.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000010_s1_ch1.wav
# Dominant frequency: 40.00 Hz
# --------------------------------------------------
# Analyzing file: 202253-16-31_Aphidoletes_aphidimyza_000042_s33_ch3.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202253-16-31_Aphidoletes_aphidimyza_000013_s41_ch0.wav
# Dominant frequency: 28.00 Hz
# --------------------------------------------------
# Analyzing file: 2022323-13-1_Aphidoletes_aphidimyza_000053_s11_ch0.wav
# Dominant frequency: 15.60 Hz
# --------------------------------------------------
# Analyzing file: 202252-18-31_Aphidoletes_aphidimyza_000032_s68_ch0.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 2022324-13-48_Aphidoletes_aphidimyza_000063_s41_ch0.wav
# Dominant frequency: 19.20 Hz
# --------------------------------------------------
# Analyzing file: 202253-16-31_Aphidoletes_aphidimyza_000012_s26_ch0.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000037_s98_ch1.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000016_s131_ch3.wav
# Dominant frequency: 18.80 Hz
# --------------------------------------------------
# Analyzing file: 202253-16-31_Aphidoletes_aphidimyza_000025_s23_ch1.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 2022323-13-1_Aphidoletes_aphidimyza_000046_s48_ch0.wav
# Dominant frequency: 18.40 Hz
# --------------------------------------------------
# Analyzing file: 202252-18-31_Aphidoletes_aphidimyza_000044_s13_ch0.wav
# Dominant frequency: 40.00 Hz
# --------------------------------------------------
# Analyzing file: 2022324-13-48_Aphidoletes_aphidimyza_000048_s8_ch0.wav
# Dominant frequency: 35.60 Hz
# --------------------------------------------------
# Analyzing file: 202252-18-31_Aphidoletes_aphidimyza_000027_s24_ch0.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000040_s40_ch3.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202253-16-31_Aphidoletes_aphidimyza_000026_s16_ch3.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 2022323-13-1_Aphidoletes_aphidimyza_000078_s3_ch0.wav
# Dominant frequency: 18.80 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000025_s105_ch1.wav
# Dominant frequency: 38.80 Hz
# --------------------------------------------------
# Analyzing file: 2022323-13-1_Aphidoletes_aphidimyza_000047_s86_ch0.wav
# Dominant frequency: 16.00 Hz
# --------------------------------------------------
# Analyzing file: 2022323-13-1_Aphidoletes_aphidimyza_000001_s11_ch0.wav
# Dominant frequency: 18.40 Hz
# --------------------------------------------------
# Analyzing file: 2022323-13-1_Aphidoletes_aphidimyza_000047_s38_ch0.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 2022324-13-48_Aphidoletes_aphidimyza_000061_s60_ch0.wav
# Dominant frequency: 35.20 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000024_s125_ch3.wav
# Dominant frequency: 38.80 Hz
# --------------------------------------------------
# Analyzing file: 2022323-13-1_Aphidoletes_aphidimyza_000061_s20_ch0.wav
# Dominant frequency: 19.60 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000037_s9_ch1.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202253-16-31_Aphidoletes_aphidimyza_000041_s41_ch0.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000054_s17_ch0.wav
# Dominant frequency: 38.80 Hz
# --------------------------------------------------
# Analyzing file: 2022323-13-1_Aphidoletes_aphidimyza_000063_s21_ch0.wav
# Dominant frequency: 19.20 Hz
# --------------------------------------------------
# Analyzing file: 202253-16-31_Aphidoletes_aphidimyza_000040_s11_ch1.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202252-18-31_Aphidoletes_aphidimyza_000036_s62_ch2.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000003_s26_ch0.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202253-16-31_Aphidoletes_aphidimyza_000023_s81_ch1.wav
# Dominant frequency: 39.20 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000006_s75_ch0.wav
# Dominant frequency: 40.00 Hz
# --------------------------------------------------
# Analyzing file: 2022323-13-1_Aphidoletes_aphidimyza_000001_s20_ch0.wav
# Dominant frequency: 4.80 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000008_s65_ch0.wav
# Dominant frequency: 29.60 Hz
# --------------------------------------------------
# Analyzing file: 202253-16-31_Aphidoletes_aphidimyza_000027_s7_ch0.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202253-16-31_Aphidoletes_aphidimyza_000052_s2_ch0.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000002_s28_ch0.wav
# Dominant frequency: 254.40 Hz
# --------------------------------------------------
# Analyzing file: 202253-16-31_Aphidoletes_aphidimyza_000025_s46_ch1.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000018_s43_ch3.wav
# Dominant frequency: 33.20 Hz
# --------------------------------------------------
# Analyzing file: 2022323-13-1_Aphidoletes_aphidimyza_000078_s14_ch0.wav
# Dominant frequency: 18.80 Hz
# --------------------------------------------------
# Analyzing file: 202253-16-31_Aphidoletes_aphidimyza_000035_s19_ch1.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202252-18-31_Aphidoletes_aphidimyza_000039_s28_ch0.wav
# Dominant frequency: 29.20 Hz
# --------------------------------------------------
# Analyzing file: 202252-18-31_Aphidoletes_aphidimyza_000057_s67_ch0.wav
# Dominant frequency: 18.80 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000037_s37_ch1.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202252-18-31_Aphidoletes_aphidimyza_000060_s2_ch0.wav
# Dominant frequency: 40.40 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000036_s50_ch3.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 2022324-13-48_Aphidoletes_aphidimyza_000055_s16_ch0.wav
# Dominant frequency: 35.60 Hz
# --------------------------------------------------
# Analyzing file: 202253-16-31_Aphidoletes_aphidimyza_000059_s1_ch0.wav
# Dominant frequency: 19.20 Hz
# --------------------------------------------------
# Analyzing file: 202253-16-31_Aphidoletes_aphidimyza_000016_s81_ch1.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202252-18-31_Aphidoletes_aphidimyza_000015_s37_ch0.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000046_s57_ch0.wav
# Dominant frequency: 3.20 Hz
# --------------------------------------------------
# Analyzing file: 202252-18-31_Aphidoletes_aphidimyza_000042_s1_ch0.wav
# Dominant frequency: 19.20 Hz
# --------------------------------------------------
# Analyzing file: 2022324-13-48_Aphidoletes_aphidimyza_000043_s31_ch0.wav
# Dominant frequency: 34.80 Hz
# --------------------------------------------------
# Analyzing file: 202252-18-31_Aphidoletes_aphidimyza_000030_s82_ch3.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202253-16-31_Aphidoletes_aphidimyza_000054_s50_ch1.wav
# Dominant frequency: 38.00 Hz
# --------------------------------------------------
# Analyzing file: 2022324-13-48_Aphidoletes_aphidimyza_000061_s45_ch0.wav
# Dominant frequency: 30.40 Hz
# --------------------------------------------------
# Analyzing file: 202253-16-31_Aphidoletes_aphidimyza_000027_s34_ch0.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000035_s49_ch0.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000016_s105_ch3.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 2022323-13-1_Aphidoletes_aphidimyza_000056_s59_ch1.wav
# Dominant frequency: 29.20 Hz
# --------------------------------------------------
# Analyzing file: 202252-18-31_Aphidoletes_aphidimyza_000024_s3_ch3.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000004_s52_ch0.wav
# Dominant frequency: 19.60 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000029_s40_ch3.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000036_s78_ch3.wav
# Dominant frequency: 2.80 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000005_s10_ch0.wav
# Dominant frequency: 40.40 Hz
# --------------------------------------------------
# Analyzing file: 2022324-13-48_Aphidoletes_aphidimyza_000059_s4_ch0.wav
# Dominant frequency: 35.60 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000046_s18_ch0.wav
# Dominant frequency: 19.60 Hz
# --------------------------------------------------
# Analyzing file: 202253-16-31_Aphidoletes_aphidimyza_000064_s5_ch0.wav
# Dominant frequency: 18.80 Hz
# --------------------------------------------------
# Analyzing file: 2022324-13-48_Aphidoletes_aphidimyza_000043_s19_ch0.wav
# Dominant frequency: 15.20 Hz
# --------------------------------------------------
# Analyzing file: 202252-18-31_Aphidoletes_aphidimyza_000037_s38_ch0.wav
# Dominant frequency: 29.60 Hz
# --------------------------------------------------
# Analyzing file: 2022324-13-48_Aphidoletes_aphidimyza_000066_s1_ch0.wav
# Dominant frequency: 35.20 Hz
# --------------------------------------------------
# Analyzing file: 2022324-13-48_Aphidoletes_aphidimyza_000050_s113_ch1.wav
# Dominant frequency: 16.00 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000022_s93_ch3.wav
# Dominant frequency: 38.80 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000030_s53_ch1.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000028_s10_ch3.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202253-16-31_Aphidoletes_aphidimyza_000019_s11_ch2.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000018_s95_ch3.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000034_s5_ch1.wav
# Dominant frequency: 40.00 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000025_s58_ch1.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000040_s36_ch3.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202253-16-31_Aphidoletes_aphidimyza_000025_s79_ch1.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202253-16-31_Aphidoletes_aphidimyza_000012_s4_ch0.wav
# Dominant frequency: 40.00 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000027_s71_ch0.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202253-16-31_Aphidoletes_aphidimyza_000046_s1_ch1.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202253-16-31_Aphidoletes_aphidimyza_000055_s39_ch0.wav
# Dominant frequency: 38.80 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000066_s8_ch0.wav
# Dominant frequency: 18.80 Hz
# --------------------------------------------------
# Analyzing file: 202253-16-31_Aphidoletes_aphidimyza_000054_s60_ch1.wav
# Dominant frequency: 19.60 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000018_s61_ch3.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 2022324-13-48_Aphidoletes_aphidimyza_000055_s45_ch0.wav
# Dominant frequency: 35.60 Hz
# --------------------------------------------------
# Analyzing file: 202252-18-31_Aphidoletes_aphidimyza_000031_s60_ch3.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000016_s47_ch3.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202252-18-31_Aphidoletes_aphidimyza_000023_s27_ch1.wav
# Dominant frequency: 38.00 Hz
# --------------------------------------------------
# Analyzing file: 2022324-13-48_Aphidoletes_aphidimyza_000058_s51_ch0.wav
# Dominant frequency: 35.60 Hz
# --------------------------------------------------
# Analyzing file: 2022324-13-48_Aphidoletes_aphidimyza_000055_s46_ch0.wav
# Dominant frequency: 35.60 Hz
# --------------------------------------------------
# Analyzing file: 202252-18-31_Aphidoletes_aphidimyza_000057_s56_ch0.wav
# Dominant frequency: 18.80 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000018_s125_ch3.wav
# Dominant frequency: 31.20 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000022_s47_ch3.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202253-16-31_Aphidoletes_aphidimyza_000017_s51_ch0.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202253-16-31_Aphidoletes_aphidimyza_000014_s50_ch0.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000034_s53_ch1.wav
# Dominant frequency: 19.20 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000038_s50_ch1.wav
# Dominant frequency: 20.00 Hz
# --------------------------------------------------
# Analyzing file: 202253-16-31_Aphidoletes_aphidimyza_000047_s12_ch0.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202252-18-31_Aphidoletes_aphidimyza_000025_s111_ch3.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202253-16-31_Aphidoletes_aphidimyza_000021_s100_ch2.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202252-18-31_Aphidoletes_aphidimyza_000033_s61_ch0.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 2022324-13-48_Aphidoletes_aphidimyza_000049_s15_ch0.wav
# Dominant frequency: 38.40 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000000_s14_ch0.wav
# Dominant frequency: 38.80 Hz
# --------------------------------------------------
# Analyzing file: 202253-16-31_Aphidoletes_aphidimyza_000013_s43_ch0.wav
# Dominant frequency: 29.20 Hz
# --------------------------------------------------
# Analyzing file: 2022323-13-1_Aphidoletes_aphidimyza_000056_s29_ch1.wav
# Dominant frequency: 18.40 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000038_s59_ch1.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000016_s102_ch3.wav
# Dominant frequency: 38.00 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000003_s72_ch0.wav
# Dominant frequency: 38.40 Hz
# --------------------------------------------------
# Analyzing file: 202253-16-31_Aphidoletes_aphidimyza_000056_s11_ch0.wav
# Dominant frequency: 38.80 Hz
# --------------------------------------------------
# Analyzing file: 2022323-13-1_Aphidoletes_aphidimyza_000000_s16_ch0.wav
# Dominant frequency: 9.20 Hz
# --------------------------------------------------
# Analyzing file: 202253-16-31_Aphidoletes_aphidimyza_000022_s4_ch1.wav
# Dominant frequency: 9.60 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000015_s70_ch0.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000056_s7_ch0.wav
# Dominant frequency: 15.60 Hz
# --------------------------------------------------
# Analyzing file: 202253-16-31_Aphidoletes_aphidimyza_000014_s29_ch0.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202253-16-31_Aphidoletes_aphidimyza_000054_s12_ch1.wav
# Dominant frequency: 16.40 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000048_s1_ch0.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202253-16-31_Aphidoletes_aphidimyza_000029_s158_ch2.wav
# Dominant frequency: 133.20 Hz
# --------------------------------------------------
# Analyzing file: 202253-16-31_Aphidoletes_aphidimyza_000048_s15_ch0.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000039_s12_ch1.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202253-16-31_Aphidoletes_aphidimyza_000032_s34_ch2.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000006_s44_ch0.wav
# Dominant frequency: 38.40 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000005_s9_ch0.wav
# Dominant frequency: 29.60 Hz
# --------------------------------------------------
# Analyzing file: 2022323-13-1_Aphidoletes_aphidimyza_000046_s4_ch0.wav
# Dominant frequency: 34.00 Hz
# --------------------------------------------------
# Analyzing file: 202253-16-31_Aphidoletes_aphidimyza_000020_s69_ch2.wav
# Dominant frequency: 139.60 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000048_s25_ch0.wav
# Dominant frequency: 30.80 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000015_s114_ch0.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000015_s96_ch0.wav
# Dominant frequency: 19.60 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000023_s27_ch1.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 2022324-13-48_Aphidoletes_aphidimyza_000070_s18_ch0.wav
# Dominant frequency: 19.20 Hz
# --------------------------------------------------
# Analyzing file: 202253-16-31_Aphidoletes_aphidimyza_000010_s31_ch0.wav
# Dominant frequency: 38.80 Hz
# --------------------------------------------------
# Analyzing file: 2022324-13-48_Aphidoletes_aphidimyza_000058_s28_ch0.wav
# Dominant frequency: 35.60 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000006_s41_ch0.wav
# Dominant frequency: 19.60 Hz
# --------------------------------------------------
# Analyzing file: 2022323-13-1_Aphidoletes_aphidimyza_000067_s18_ch0.wav
# Dominant frequency: 19.60 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000025_s90_ch1.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202252-18-31_Aphidoletes_aphidimyza_000023_s88_ch1.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000028_s44_ch3.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 2022323-13-1_Aphidoletes_aphidimyza_000073_s11_ch0.wav
# Dominant frequency: 29.20 Hz
# --------------------------------------------------
# Analyzing file: 2022324-13-48_Aphidoletes_aphidimyza_000043_s7_ch0.wav
# Dominant frequency: 16.00 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000010_s12_ch1.wav
# Dominant frequency: 38.40 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000023_s108_ch1.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202253-16-31_Aphidoletes_aphidimyza_000008_s6_ch0.wav
# Dominant frequency: 38.00 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000025_s72_ch1.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000055_s21_ch0.wav
# Dominant frequency: 36.00 Hz
# --------------------------------------------------
# Analyzing file: 2022323-13-1_Aphidoletes_aphidimyza_000078_s30_ch0.wav
# Dominant frequency: 18.80 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000033_s46_ch3.wav
# Dominant frequency: 38.80 Hz
# --------------------------------------------------
# Analyzing file: 202252-18-31_Aphidoletes_aphidimyza_000030_s74_ch3.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202253-16-31_Aphidoletes_aphidimyza_000050_s22_ch0.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 2022323-13-1_Aphidoletes_aphidimyza_000077_s5_ch0.wav
# Dominant frequency: 18.80 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000004_s2_ch0.wav
# Dominant frequency: 37.60 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000045_s16_ch1.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202253-16-31_Aphidoletes_aphidimyza_000054_s39_ch1.wav
# Dominant frequency: 16.40 Hz
# --------------------------------------------------
# Analyzing file: 202253-16-31_Aphidoletes_aphidimyza_000028_s43_ch1.wav
# Dominant frequency: 38.80 Hz
# --------------------------------------------------
# Analyzing file: 202253-16-31_Aphidoletes_aphidimyza_000023_s98_ch1.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000021_s49_ch0.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202253-16-31_Aphidoletes_aphidimyza_000016_s9_ch1.wav
# Dominant frequency: 22.40 Hz
# --------------------------------------------------
# Analyzing file: 202252-18-31_Aphidoletes_aphidimyza_000025_s110_ch3.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 2022324-13-48_Aphidoletes_aphidimyza_000050_s59_ch1.wav
# Dominant frequency: 16.00 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000033_s73_ch3.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202253-16-31_Aphidoletes_aphidimyza_000023_s23_ch1.wav
# Dominant frequency: 38.40 Hz
# --------------------------------------------------
# Analyzing file: 202253-16-31_Aphidoletes_aphidimyza_000036_s40_ch1.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202253-16-31_Aphidoletes_aphidimyza_000054_s32_ch1.wav
# Dominant frequency: 38.00 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000025_s2_ch1.wav
# Dominant frequency: 38.00 Hz
# --------------------------------------------------
# Analyzing file: 2022323-13-1_Aphidoletes_aphidimyza_000007_s1_ch0.wav
# Dominant frequency: 18.80 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000022_s116_ch3.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000026_s130_ch3.wav
# Dominant frequency: 40.80 Hz
# --------------------------------------------------
# Analyzing file: 202252-18-31_Aphidoletes_aphidimyza_000028_s109_ch3.wav
# Dominant frequency: 18.40 Hz
# --------------------------------------------------
# Analyzing file: 2022323-13-1_Aphidoletes_aphidimyza_000053_s19_ch0.wav
# Dominant frequency: 16.00 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000035_s40_ch0.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 2022324-13-48_Aphidoletes_aphidimyza_000061_s9_ch0.wav
# Dominant frequency: 28.80 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000066_s17_ch0.wav
# Dominant frequency: 18.80 Hz
# --------------------------------------------------
# Analyzing file: 202252-18-31_Aphidoletes_aphidimyza_000025_s34_ch3.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202252-18-31_Aphidoletes_aphidimyza_000036_s65_ch2.wav
# Dominant frequency: 18.40 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000022_s77_ch3.wav
# Dominant frequency: 37.60 Hz
# --------------------------------------------------
# Analyzing file: 2022323-13-1_Aphidoletes_aphidimyza_000060_s47_ch0.wav
# Dominant frequency: 35.60 Hz
# --------------------------------------------------
# Analyzing file: 2022323-13-1_Aphidoletes_aphidimyza_000071_s8_ch0.wav
# Dominant frequency: 28.80 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000051_s19_ch0.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000029_s31_ch3.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202253-16-31_Aphidoletes_aphidimyza_000003_s28_ch0.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000001_s22_ch0.wav
# Dominant frequency: 29.20 Hz
# --------------------------------------------------
# Analyzing file: 202252-18-31_Aphidoletes_aphidimyza_000024_s30_ch3.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 2022324-13-48_Aphidoletes_aphidimyza_000062_s15_ch0.wav
# Dominant frequency: 19.60 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000023_s128_ch1.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 2022324-13-48_Aphidoletes_aphidimyza_000070_s30_ch0.wav
# Dominant frequency: 29.20 Hz
# --------------------------------------------------
# Analyzing file: 2022323-13-1_Aphidoletes_aphidimyza_000053_s7_ch0.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000016_s76_ch3.wav
# Dominant frequency: 38.80 Hz
# --------------------------------------------------
# Analyzing file: 2022324-13-48_Aphidoletes_aphidimyza_000060_s24_ch0.wav
# Dominant frequency: 29.20 Hz
# --------------------------------------------------
# Analyzing file: 2022323-13-1_Aphidoletes_aphidimyza_000071_s13_ch0.wav
# Dominant frequency: 34.80 Hz
# --------------------------------------------------
# Analyzing file: 2022324-13-48_Aphidoletes_aphidimyza_000049_s4_ch0.wav
# Dominant frequency: 35.60 Hz
# --------------------------------------------------
# Analyzing file: 202252-18-31_Aphidoletes_aphidimyza_000032_s42_ch0.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000025_s55_ch1.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202252-18-31_Aphidoletes_aphidimyza_000029_s15_ch3.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000043_s30_ch0.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 2022323-13-1_Aphidoletes_aphidimyza_000078_s15_ch0.wav
# Dominant frequency: 18.80 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000034_s6_ch1.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202252-18-31_Aphidoletes_aphidimyza_000011_s26_ch0.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202253-16-31_Aphidoletes_aphidimyza_000035_s34_ch1.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000032_s46_ch3.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202252-18-31_Aphidoletes_aphidimyza_000015_s51_ch0.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000014_s68_ch0.wav
# Dominant frequency: 38.80 Hz
# --------------------------------------------------
# Analyzing file: 202253-16-31_Aphidoletes_aphidimyza_000055_s23_ch0.wav
# Dominant frequency: 19.60 Hz
# --------------------------------------------------
# Analyzing file: 2022324-13-48_Aphidoletes_aphidimyza_000063_s50_ch0.wav
# Dominant frequency: 28.80 Hz
# --------------------------------------------------
# Analyzing file: 202252-18-31_Aphidoletes_aphidimyza_000023_s1_ch1.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202253-16-31_Aphidoletes_aphidimyza_000039_s50_ch3.wav
# Dominant frequency: 38.80 Hz
# --------------------------------------------------
# Analyzing file: 2022324-13-48_Aphidoletes_aphidimyza_000060_s25_ch0.wav
# Dominant frequency: 29.20 Hz
# --------------------------------------------------
# Analyzing file: 202252-18-31_Aphidoletes_aphidimyza_000028_s113_ch3.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 2022324-13-48_Aphidoletes_aphidimyza_000048_s14_ch0.wav
# Dominant frequency: 4.80 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000011_s82_ch0.wav
# Dominant frequency: 2.00 Hz
# --------------------------------------------------
# Analyzing file: 2022323-13-1_Aphidoletes_aphidimyza_000050_s32_ch0.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000017_s48_ch3.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000027_s28_ch0.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000049_s15_ch0.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000021_s87_ch0.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000016_s123_ch3.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202253-16-31_Aphidoletes_aphidimyza_000049_s26_ch0.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000013_s12_ch0.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 2022323-13-1_Aphidoletes_aphidimyza_000053_s29_ch0.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000032_s90_ch3.wav
# Dominant frequency: 30.80 Hz
# --------------------------------------------------
# Analyzing file: 202252-18-31_Aphidoletes_aphidimyza_000030_s85_ch3.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 2022324-13-48_Aphidoletes_aphidimyza_000050_s2_ch1.wav
# Dominant frequency: 35.60 Hz
# --------------------------------------------------
# Analyzing file: 202252-18-31_Aphidoletes_aphidimyza_000021_s18_ch0.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202253-16-31_Aphidoletes_aphidimyza_000040_s46_ch1.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 2022323-13-1_Aphidoletes_aphidimyza_000071_s11_ch0.wav
# Dominant frequency: 29.20 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000028_s4_ch3.wav
# Dominant frequency: 18.40 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000020_s78_ch3.wav
# Dominant frequency: 38.80 Hz
# --------------------------------------------------
# Analyzing file: 202252-18-31_Aphidoletes_aphidimyza_000030_s65_ch3.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202253-16-31_Aphidoletes_aphidimyza_000013_s30_ch0.wav
# Dominant frequency: 35.60 Hz
# --------------------------------------------------
# Analyzing file: 202253-16-31_Aphidoletes_aphidimyza_000026_s90_ch3.wav
# Dominant frequency: 38.80 Hz
# --------------------------------------------------
# Analyzing file: 2022324-13-48_Aphidoletes_aphidimyza_000032_s6_ch0.wav
# Dominant frequency: 36.80 Hz
# --------------------------------------------------
# Analyzing file: 202253-16-31_Aphidoletes_aphidimyza_000054_s44_ch1.wav
# Dominant frequency: 18.80 Hz
# --------------------------------------------------
# Analyzing file: 202252-18-31_Aphidoletes_aphidimyza_000027_s27_ch0.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202253-16-31_Aphidoletes_aphidimyza_000070_s4_ch0.wav
# Dominant frequency: 18.80 Hz
# --------------------------------------------------
# Analyzing file: 202252-18-31_Aphidoletes_aphidimyza_000053_s3_ch0.wav
# Dominant frequency: 18.80 Hz
# --------------------------------------------------
# Analyzing file: 202252-18-31_Aphidoletes_aphidimyza_000034_s36_ch2.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000038_s39_ch1.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000003_s53_ch0.wav
# Dominant frequency: 21.20 Hz
# --------------------------------------------------
# Analyzing file: 202253-16-31_Aphidoletes_aphidimyza_000054_s3_ch1.wav
# Dominant frequency: 38.00 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000034_s38_ch1.wav
# Dominant frequency: 34.80 Hz
# --------------------------------------------------
# Analyzing file: 2022323-13-1_Aphidoletes_aphidimyza_000077_s44_ch0.wav
# Dominant frequency: 18.80 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000016_s95_ch3.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000023_s4_ch1.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000049_s21_ch0.wav
# Dominant frequency: 39.60 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000032_s31_ch3.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000034_s8_ch1.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000040_s2_ch3.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202253-16-31_Aphidoletes_aphidimyza_000048_s6_ch0.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000024_s84_ch3.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202253-16-31_Aphidoletes_aphidimyza_000031_s102_ch2.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000016_s92_ch3.wav
# Dominant frequency: 37.60 Hz
# --------------------------------------------------
# Analyzing file: 202253-16-31_Aphidoletes_aphidimyza_000025_s90_ch1.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202253-16-31_Aphidoletes_aphidimyza_000003_s8_ch0.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 2022323-13-1_Aphidoletes_aphidimyza_000052_s12_ch2.wav
# Dominant frequency: 16.00 Hz
# --------------------------------------------------
# Analyzing file: 202253-16-31_Aphidoletes_aphidimyza_000039_s77_ch3.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 2022324-13-48_Aphidoletes_aphidimyza_000057_s12_ch0.wav
# Dominant frequency: 39.20 Hz
# --------------------------------------------------
# Analyzing file: 202253-16-31_Aphidoletes_aphidimyza_000014_s31_ch0.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202252-18-31_Aphidoletes_aphidimyza_000029_s55_ch3.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202252-18-31_Aphidoletes_aphidimyza_000026_s46_ch0.wav
# Dominant frequency: 22.40 Hz
# --------------------------------------------------
# Analyzing file: 202252-18-31_Aphidoletes_aphidimyza_000035_s9_ch3.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 2022323-13-1_Aphidoletes_aphidimyza_000066_s21_ch0.wav
# Dominant frequency: 30.40 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000032_s38_ch3.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202252-18-31_Aphidoletes_aphidimyza_000015_s35_ch0.wav
# Dominant frequency: 40.80 Hz
# --------------------------------------------------
# Analyzing file: 202252-18-31_Aphidoletes_aphidimyza_000034_s71_ch2.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000022_s58_ch3.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 2022324-13-48_Aphidoletes_aphidimyza_000059_s43_ch0.wav
# Dominant frequency: 35.20 Hz
# --------------------------------------------------
# Analyzing file: 202252-18-31_Aphidoletes_aphidimyza_000015_s3_ch0.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 2022324-13-48_Aphidoletes_aphidimyza_000061_s10_ch0.wav
# Dominant frequency: 16.40 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000033_s44_ch3.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000002_s20_ch0.wav
# Dominant frequency: 18.80 Hz
# --------------------------------------------------
# Analyzing file: 202253-16-31_Aphidoletes_aphidimyza_000024_s37_ch1.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000061_s5_ch0.wav
# Dominant frequency: 18.80 Hz
# --------------------------------------------------
# Analyzing file: 202252-18-31_Aphidoletes_aphidimyza_000041_s21_ch0.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202253-16-31_Aphidoletes_aphidimyza_000024_s65_ch1.wav
# Dominant frequency: 37.20 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000007_s73_ch0.wav
# Dominant frequency: 37.20 Hz
# --------------------------------------------------
# Analyzing file: 202252-18-31_Aphidoletes_aphidimyza_000032_s90_ch0.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202252-18-31_Aphidoletes_aphidimyza_000059_s22_ch0.wav
# Dominant frequency: 18.80 Hz
# --------------------------------------------------
# Analyzing file: 202252-18-31_Aphidoletes_aphidimyza_000059_s24_ch0.wav
# Dominant frequency: 18.80 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000023_s125_ch1.wav
# Dominant frequency: 29.20 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000037_s89_ch1.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202252-18-31_Aphidoletes_aphidimyza_000031_s70_ch3.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202253-16-31_Aphidoletes_aphidimyza_000030_s69_ch1.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000066_s40_ch0.wav
# Dominant frequency: 18.80 Hz
# --------------------------------------------------
# Analyzing file: 202253-16-31_Aphidoletes_aphidimyza_000027_s73_ch0.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 2022324-13-48_Aphidoletes_aphidimyza_000056_s21_ch0.wav
# Dominant frequency: 4.00 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000039_s37_ch1.wav
# Dominant frequency: 3.60 Hz
# ...
# Dominant frequency: 28.00 Hz
# --------------------------------------------------
# Analyzing file: 2022324-13-48_Aphidoletes_aphidimyza_000063_s10_ch0.wav
# Dominant frequency: 18.80 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000031_s65_ch0.wav
# Dominant frequency: 15.20 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000016_s72_ch3.wav
# Dominant frequency: 39.20 Hz
# --------------------------------------------------
# Analyzing file: 2022323-13-1_Aphidoletes_aphidimyza_000052_s3_ch2.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 2022323-13-1_Aphidoletes_aphidimyza_000051_s6_ch0.wav
# Dominant frequency: 15.60 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000025_s29_ch1.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202252-18-31_Aphidoletes_aphidimyza_000026_s65_ch0.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 2022324-13-48_Aphidoletes_aphidimyza_000061_s56_ch0.wav
# Dominant frequency: 34.80 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000012_s2_ch3.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202253-16-31_Aphidoletes_aphidimyza_000013_s39_ch0.wav
# Dominant frequency: 38.80 Hz
# --------------------------------------------------
# Analyzing file: 202252-18-31_Aphidoletes_aphidimyza_000024_s40_ch3.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000022_s81_ch3.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000043_s32_ch0.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000007_s11_ch0.wav
# Dominant frequency: 17.60 Hz
# --------------------------------------------------
# Analyzing file: 202252-18-31_Aphidoletes_aphidimyza_000057_s94_ch0.wav
# Dominant frequency: 18.80 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000020_s131_ch3.wav
# Dominant frequency: 28.80 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000058_s3_ch0.wav
# Dominant frequency: 29.20 Hz
# --------------------------------------------------
# Analyzing file: 202253-16-31_Aphidoletes_aphidimyza_000015_s23_ch0.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 2022324-13-48_Aphidoletes_aphidimyza_000067_s17_ch0.wav
# Dominant frequency: 36.80 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000034_s19_ch1.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000044_s24_ch3.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202252-18-31_Aphidoletes_aphidimyza_000026_s61_ch0.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202253-16-31_Aphidoletes_aphidimyza_000024_s107_ch1.wav
# Dominant frequency: 29.60 Hz
# --------------------------------------------------
# Analyzing file: 202252-18-31_Aphidoletes_aphidimyza_000058_s39_ch0.wav
# Dominant frequency: 18.80 Hz
# --------------------------------------------------
# Analyzing file: 202253-16-31_Aphidoletes_aphidimyza_000039_s2_ch3.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202253-16-31_Aphidoletes_aphidimyza_000040_s32_ch1.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202253-16-31_Aphidoletes_aphidimyza_000039_s64_ch3.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202253-16-31_Aphidoletes_aphidimyza_000021_s94_ch2.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 2022324-13-48_Aphidoletes_aphidimyza_000063_s21_ch0.wav
# Dominant frequency: 28.40 Hz
# --------------------------------------------------
# Analyzing file: 202253-16-31_Aphidoletes_aphidimyza_000010_s32_ch0.wav
# Dominant frequency: 40.00 Hz
# --------------------------------------------------
# Analyzing file: 2022324-13-48_Aphidoletes_aphidimyza_000064_s49_ch0.wav
# Dominant frequency: 19.60 Hz
# --------------------------------------------------
# Analyzing file: 2022324-13-48_Aphidoletes_aphidimyza_000043_s40_ch0.wav
# Dominant frequency: 16.00 Hz
# --------------------------------------------------
# Analyzing file: 202252-18-31_Aphidoletes_aphidimyza_000018_s6_ch0.wav
# Dominant frequency: 31.20 Hz
# --------------------------------------------------
# Analyzing file: 202253-16-31_Aphidoletes_aphidimyza_000039_s24_ch3.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000058_s9_ch0.wav
# Dominant frequency: 18.00 Hz
# --------------------------------------------------
# Analyzing file: 202253-16-31_Aphidoletes_aphidimyza_000040_s27_ch1.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202253-16-31_Aphidoletes_aphidimyza_000024_s15_ch1.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202252-18-31_Aphidoletes_aphidimyza_000032_s4_ch0.wav
# Dominant frequency: 19.20 Hz
# --------------------------------------------------
# Analyzing file: 202253-16-31_Aphidoletes_aphidimyza_000020_s130_ch2.wav
# Dominant frequency: 140.40 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000062_s22_ch0.wav
# Dominant frequency: 18.80 Hz
# --------------------------------------------------
# Analyzing file: 202252-18-31_Aphidoletes_aphidimyza_000024_s14_ch3.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000011_s79_ch0.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202253-16-31_Aphidoletes_aphidimyza_000023_s60_ch1.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000055_s15_ch0.wav
# Dominant frequency: 36.00 Hz
# --------------------------------------------------
# Analyzing file: 202253-16-31_Aphidoletes_aphidimyza_000030_s39_ch1.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 2022324-13-48_Aphidoletes_aphidimyza_000064_s73_ch0.wav
# Dominant frequency: 30.40 Hz
# --------------------------------------------------
# Analyzing file: 202253-16-31_Aphidoletes_aphidimyza_000025_s40_ch1.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000038_s85_ch1.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000017_s54_ch3.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000029_s109_ch3.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000005_s28_ch0.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 2022323-13-1_Aphidoletes_aphidimyza_000060_s27_ch0.wav
# Dominant frequency: 35.60 Hz
# --------------------------------------------------
# Analyzing file: 2022324-13-48_Aphidoletes_aphidimyza_000074_s17_ch0.wav
# Dominant frequency: 18.80 Hz
# --------------------------------------------------
# Analyzing file: 202252-18-31_Aphidoletes_aphidimyza_000030_s35_ch3.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202252-18-31_Aphidoletes_aphidimyza_000015_s27_ch0.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000025_s7_ch1.wav
# Dominant frequency: 40.40 Hz
# --------------------------------------------------
# Analyzing file: 202253-16-31_Aphidoletes_aphidimyza_000009_s41_ch0.wav
# Dominant frequency: 36.80 Hz
# --------------------------------------------------
# Analyzing file: 202253-16-31_Aphidoletes_aphidimyza_000011_s4_ch1.wav
# Dominant frequency: 38.80 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000014_s112_ch0.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000062_s28_ch0.wav
# Dominant frequency: 18.80 Hz
# --------------------------------------------------
# Analyzing file: 202252-18-31_Aphidoletes_aphidimyza_000026_s8_ch0.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 2022323-13-1_Aphidoletes_aphidimyza_000062_s9_ch0.wav
# Dominant frequency: 35.60 Hz
# --------------------------------------------------
# Analyzing file: 202252-18-31_Aphidoletes_aphidimyza_000048_s1_ch0.wav
# Dominant frequency: 30.00 Hz
# --------------------------------------------------
# Analyzing file: 202253-16-31_Aphidoletes_aphidimyza_000040_s28_ch1.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202253-16-31_Aphidoletes_aphidimyza_000018_s39_ch0.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000021_s114_ch0.wav
# Dominant frequency: 38.80 Hz
# --------------------------------------------------
# Analyzing file: 202252-18-31_Aphidoletes_aphidimyza_000058_s47_ch0.wav
# Dominant frequency: 18.80 Hz
# --------------------------------------------------
# Analyzing file: 202253-16-31_Aphidoletes_aphidimyza_000016_s32_ch1.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202253-16-31_Aphidoletes_aphidimyza_000025_s66_ch1.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202253-16-31_Aphidoletes_aphidimyza_000035_s41_ch1.wav
# Dominant frequency: 18.80 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000014_s13_ch0.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000040_s19_ch3.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202253-16-31_Aphidoletes_aphidimyza_000057_s20_ch0.wav
# Dominant frequency: 18.40 Hz
# --------------------------------------------------
# Analyzing file: 2022324-13-48_Aphidoletes_aphidimyza_000051_s28_ch0.wav
# Dominant frequency: 35.60 Hz
# --------------------------------------------------
# Analyzing file: 202253-16-31_Aphidoletes_aphidimyza_000046_s28_ch1.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 2022324-13-48_Aphidoletes_aphidimyza_000055_s39_ch0.wav
# Dominant frequency: 35.60 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000066_s43_ch0.wav
# Dominant frequency: 18.80 Hz
# --------------------------------------------------
# Analyzing file: 202253-16-31_Aphidoletes_aphidimyza_000008_s12_ch0.wav
# Dominant frequency: 39.20 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000018_s40_ch3.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000028_s68_ch3.wav
# Dominant frequency: 131.20 Hz
# --------------------------------------------------
# Analyzing file: 2022324-13-48_Aphidoletes_aphidimyza_000064_s54_ch0.wav
# Dominant frequency: 38.40 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000029_s38_ch3.wav
# Dominant frequency: 18.40 Hz
# --------------------------------------------------
# Analyzing file: 2022323-13-1_Aphidoletes_aphidimyza_000051_s37_ch0.wav
# Dominant frequency: 16.00 Hz
# --------------------------------------------------
# Analyzing file: 202253-16-31_Aphidoletes_aphidimyza_000031_s23_ch2.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000011_s31_ch0.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000023_s49_ch1.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 2022324-13-48_Aphidoletes_aphidimyza_000043_s17_ch0.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202253-16-31_Aphidoletes_aphidimyza_000025_s22_ch1.wav
# Dominant frequency: 20.00 Hz
# --------------------------------------------------
# Analyzing file: 2022323-13-1_Aphidoletes_aphidimyza_000050_s22_ch0.wav
# Dominant frequency: 16.00 Hz
# --------------------------------------------------
# Analyzing file: 202253-16-31_Aphidoletes_aphidimyza_000021_s102_ch2.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202253-16-31_Aphidoletes_aphidimyza_000031_s11_ch2.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202252-18-31_Aphidoletes_aphidimyza_000030_s87_ch3.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000014_s62_ch0.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202253-16-31_Aphidoletes_aphidimyza_000039_s72_ch3.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000024_s90_ch3.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202253-16-31_Aphidoletes_aphidimyza_000043_s4_ch3.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 2022324-13-48_Aphidoletes_aphidimyza_000055_s31_ch0.wav
# Dominant frequency: 35.60 Hz
# --------------------------------------------------
# Analyzing file: 202253-16-31_Aphidoletes_aphidimyza_000015_s41_ch0.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000024_s128_ch3.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202254-16-17_Aphidoletes_aphidimyza_000025_s26_ch1.wav
# Dominant frequency: 7.60 Hz
# --------------------------------------------------
# Analyzing file: 202253-16-31_Aphidoletes_aphidimyza_000014_s7_ch0.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202252-18-31_Aphidoletes_aphidimyza_000053_s4_ch0.wav
# Dominant frequency: 18.80 Hz
# --------------------------------------------------
# Analyzing file: 2022324-13-48_Aphidoletes_aphidimyza_000061_s7_ch0.wav
# Dominant frequency: 35.20 Hz
# --------------------------------------------------
# Analyzing file: 202253-16-31_Aphidoletes_aphidimyza_000056_s3_ch0.wav
# Dominant frequency: 30.00 Hz
# --------------------------------------------------
# Analyzing file: 2022323-13-1_Aphidoletes_aphidimyza_000043_s2_ch0.wav
# Dominant frequency: 3.60 Hz
# --------------------------------------------------
# Analyzing file: 202253-16-31_Aphidoletes_aphidimyza_000061_s18_ch0.wav
# Dominant frequency: 18.80 Hz

# %%
len(audio_data_dict)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 len(audio_data_dict)
#
# NameError: name 'audio_data_dict' is not defined

# %%
from scipy import stats
dominant_freqs_array = np.array(dominant_freqs_all)

# Mean
mean_freq = np.mean(dominant_freqs_array)

# Median
median_freq = np.median(dominant_freqs_array)

# Mode
mode_freq = stats.mode(dominant_freqs_array)[0]  # Mode returns an array, we extract the value

# Print results
print(f"Mean Dominant Frequency: {mean_freq:.2f} Hz")
print(f"Median Dominant Frequency: {median_freq:.2f} Hz")
print(f"Mode Dominant Frequency: {mode_freq:.2f} Hz")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 from scipy import stats
# ----> 2 dominant_freqs_array = np.array(dominant_freqs_all)
#       4 # Mean
#       5 mean_freq = np.mean(dominant_freqs_array)
#
# NameError: name 'np' is not defined

# %%
# White Noise Generation with Bandpass Filtering
def generate_filtered_white_noise(duration, sample_rate, low_freq, high_freq, order=3):
    t = np.linspace(0, duration, int(sample_rate * duration), endpoint=False)
    white_noise = np.random.normal(0, 0.1, len(t))  # Generate white noise
    
    # Bandpass filter (using filtfilt)
    from scipy.signal import butter, filtfilt
    nyquist = 0.5 * sample_rate
    low = low_freq / nyquist
    high = high_freq / nyquist
    b, a = butter(order, [low, high], btype='band')
    filtered_noise = filtfilt(b, a, white_noise)  # Apply zero-phase filtering
    return filtered_noise, t

# %%
def generate_random_pulses(duration, sample_rate, low_freq, high_freq, pulse_duration=0.25):
    t = np.linspace(0, duration, int(sample_rate * duration), endpoint=False)
    pulses = np.zeros_like(t)

    # Generate random onset times
    num_pulses = int(duration // pulse_duration)
    onset_times = np.sort(np.random.choice(t, num_pulses, replace=False))  # Random start times
    
    for onset in onset_times:
        pulse_freq = np.random.uniform(low_freq, high_freq)  # Random frequency for the pulse
        pulse_t = t[(t >= onset) & (t < onset + pulse_duration)]  # Time range for the pulse
        pulse_signal = np.sin(2 * np.pi * pulse_freq * (pulse_t - onset))  # Generate sine wave
        pulses[(t >= onset) & (t < onset + pulse_duration)] = pulse_signal
    
    return pulses

# %%
# Scale the combined signal
def scale_signal(signal, min_value, max_value):
    min_signal = np.min(signal)
    max_signal = np.max(signal)
    scale_factor = (max_value - min_value) / (max_signal - min_signal)
    scaled_signal = (signal - min_signal) * scale_factor + min_value
    return scaled_signal

# %%
duration = 2.5
sample_rate= 16000
low_freq = 0.4
high_freq = 50

filtered_noise,t = generate_filtered_white_noise(duration,sample_rate,low_freq,high_freq)
pulse_signal = generate_random_pulses(duration,sample_rate,low_freq,high_freq)
# Combine signals
combined_signal = filtered_noise + pulse_signal

# Scale combined signal to target range
scaled_combined_signal = scale_signal(combined_signal, -9.787, 10.209)

# Plot
plt.figure(figsize=(12, 4))
plt.plot(scaled_combined_signal)
plt.title("Final Disruptive Signal (White Noise + Pulses, Scaled)")
plt.xlabel("Time (s)")
plt.ylabel("Amplitude")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 6
#       3 low_freq = 0.4
#       4 high_freq = 50
# ----> 6 filtered_noise,t = generate_filtered_white_noise(duration,sample_rate,low_freq,high_freq)
#       7 pulse_signal = generate_random_pulses(duration,sample_rate,low_freq,high_freq)
#       8 # Combine signals
#
# NameError: name 'generate_filtered_white_noise' is not defined

# %%
# Spectrogram for natural signal
plot_spectrogram(audio_data, sample_rate)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 # Spectrogram for natural signal
# ----> 2 plot_spectrogram(audio_data, sample_rate)
#
# NameError: name 'plot_spectrogram' is not defined

# %%
plot_spectrogram(combined_signal, sample_rate)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 plot_spectrogram(combined_signal, sample_rate)
#
# NameError: name 'plot_spectrogram' is not defined

# %%
import numpy as np

def spectral_overlap(pest_signal, disrupt_signal, sample_rate, freq_range=(20, 100)):
    """
    Computes the spectral overlap between pest and disruptive signals.

    Args:
        pest_signal (array): Pest sound signal.
        disrupt_signal (array): Disruptive signal.
        sample_rate (int): Sample rate of the signals.
        freq_range (tuple): Target frequency range (min_freq, max_freq).

    Returns:
        overlap_ratio (float): The ratio of overlap between the pest and disruptive signals.
    """
    # Compute FFT of both signals
    pest_fft = np.fft.fft(pest_signal)
    disrupt_fft = np.fft.fft(disrupt_signal)
    freqs = np.fft.fftfreq(len(pest_signal), d=1/sample_rate)

    # Select frequencies within the target range
    freq_mask = (freqs >= freq_range[0]) & (freqs <= freq_range[1])
    pest_power = np.abs(pest_fft[freq_mask]) ** 2
    disrupt_power = np.abs(disrupt_fft[freq_mask]) ** 2

    # Compute overlap ratio
    overlap = np.sum(np.minimum(pest_power, disrupt_power)) / np.sum(pest_power)
    return overlap
